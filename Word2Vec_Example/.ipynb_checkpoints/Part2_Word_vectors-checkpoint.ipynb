# %% [markdown]
# https://www.kaggle.com/c/word2vec-nlp-tutorial#part-2-word-vectors

# %%
import pandas as pd

# Read data from files 
train = pd.read_csv( "./data/labeledTrainData.tsv", header=0, 
 delimiter="\t", quoting=3 )
test = pd.read_csv( "./data/testData.tsv", header=0, delimiter="\t", quoting=3 )
unlabeled_train = pd.read_csv( "./data/unlabeledTrainData.tsv", header=0, 
 delimiter="\t", quoting=3 )

# Verify the number of reviews that were read (100,000 in total)
print("Read %d labeled train reviews, %d labeled test reviews, " \
 "and %d unlabeled reviews\n" % (train["review"].size,  
 test["review"].size, unlabeled_train["review"].size ))
# Out:
# Read 25000 labeled train reviews, 25000 labeled test reviews, and 50000 unlabeled reviews

# %%
# Import various modules for string cleaning
from bs4 import BeautifulSoup
import re
from nltk.corpus import stopwords

def review_to_wordlist( review, remove_stopwords=False ):
    # Function to convert a document to a sequence of words,
    # optionally removing stop words.  Returns a list of words.
    #
    # 1. Remove HTML
    review_text = BeautifulSoup(review).get_text()
    #  
    # 2. Remove non-letters
    review_text = re.sub("[^a-zA-Z]"," ", review_text)
    #
    # 3. Convert words to lower case and split them
    words = review_text.lower().split()
    #
    # 4. Optionally remove stop words (false by default)
    if remove_stopwords:
        stops = set(stopwords.words("english"))
        words = [w for w in words if not w in stops]
    #
    # 5. Return a list of words
    return(words)

# %%
# Download the punkt tokenizer for sentence splitting
import nltk.data
# nltk.download()   

# Load the punkt tokenizer
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')

# Define a function to split a review into parsed sentences
def review_to_sentences( review, tokenizer, remove_stopwords=False ):
    # Function to split a review into parsed sentences. Returns a 
    # list of sentences, where each sentence is a list of words
    #
    # 1. Use the NLTK tokenizer to split the paragraph into sentences
    raw_sentences = tokenizer.tokenize(review.strip())
    #
    # 2. Loop over each sentence
    sentences = []
    for raw_sentence in raw_sentences:
        # If a sentence is empty, skip it
        if len(raw_sentence) > 0:
            # Otherwise, call review_to_wordlist to get a list of words
            sentences.append( review_to_wordlist( raw_sentence, \
              remove_stopwords ))
    #
    # Return the list of sentences (each sentence is a list of words,
    # so this returns a list of lists
    return sentences

# %%
sentences = []  # Initialize an empty list of sentences

print("Parsing sentences from training set")
for review in train["review"]:
    sentences += review_to_sentences(review, tokenizer)

print("Parsing sentences from unlabeled set")
for review in unlabeled_train["review"]:
    sentences += review_to_sentences(review, tokenizer)
# Out:
# Parsing sentences from training set
# C:\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# C:\Anaconda3\lib\site-packages\bs4\__init__.py:219: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Anaconda3\lib\site-packages\bs4\__init__.py:219: UserWarning: "b'...'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Anaconda3\lib\site-packages\bs4\__init__.py:282: UserWarning: "http://www.happierabroad.com"" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# Parsing sentences from unlabeled set
# C:\Anaconda3\lib\site-packages\bs4\__init__.py:282: UserWarning: "http://www.archive.org/details/LovefromaStranger"" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\Anaconda3\lib\site-packages\bs4\__init__.py:282: UserWarning: "http://www.loosechangeguide.com/LooseChangeGuide.html"" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\Anaconda3\lib\site-packages\bs4\__init__.py:219: UserWarning: "b'... ...'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Anaconda3\lib\site-packages\bs4\__init__.py:219: UserWarning: "b'....'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Anaconda3\lib\site-packages\bs4\__init__.py:282: UserWarning: "http://www.msnbc.msn.com/id/4972055/site/newsweek/"" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\Anaconda3\lib\site-packages\bs4\__init__.py:219: UserWarning: "b'..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Anaconda3\lib\site-packages\bs4\__init__.py:282: UserWarning: "http://www.youtube.com/watch?v=a0KSqelmgN8"" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\Anaconda3\lib\site-packages\bs4\__init__.py:219: UserWarning: "b'.. .'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Anaconda3\lib\site-packages\bs4\__init__.py:282: UserWarning: "http://jake-weird.blogspot.com/2007/08/beneath.html"" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup

# %%
# Check how many sentences we have in total - should be around 850,000+
len(sentences)
# Out:
# 795538

# %%
sentences[0]
# Out:
# ['with',
#  'all',
#  'this',
#  'stuff',
#  'going',
#  'down',
#  'at',
#  'the',
#  'moment',
#  'with',
#  'mj',
#  'i',
#  've',
#  'started',
#  'listening',
#  'to',
#  'his',
#  'music',
#  'watching',
#  'the',
#  'odd',
#  'documentary',
#  'here',
#  'and',
#  'there',
#  'watched',
#  'the',
#  'wiz',
#  'and',
#  'watched',
#  'moonwalker',
#  'again']

# %%
# Import the built-in logging module and configure it so that Word2Vec 
# creates nice output messages
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s',\
    level=logging.INFO)

# Set values for various parameters
num_features = 300    # Word vector dimensionality                      
min_word_count = 40   # Minimum word count                        
num_workers = 4       # Number of threads to run in parallel
context = 10          # Context window size                                                                                    
downsampling = 1e-3   # Downsample setting for frequent words

# Initialize and train the model (this will take some time)
from gensim.models import word2vec
print("Training model...")
model = word2vec.Word2Vec(sentences, workers=num_workers, \
            size=num_features, min_count = min_word_count, \
            window = context, sample = downsampling)

# If you don't plan to train the model any further, calling 
# init_sims will make the model much more memory-efficient.
model.init_sims(replace=True)

# It can be helpful to create a meaningful model name and 
# save the model for later use. You can load it later using Word2Vec.load()
model_name = "300features_40minwords_10context"
model.save(model_name)
# Out:
# C:\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# 2018-12-01 01:13:32,094 : INFO : 'pattern' package not found; tag filters are not available for English
# 2018-12-01 01:13:32,115 : INFO : collecting all words and their counts
# 2018-12-01 01:13:32,119 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2018-12-01 01:13:32,256 : INFO : PROGRESS: at sentence #10000, processed 225803 words, keeping 17776 word types
# Training model...
# 2018-12-01 01:13:32,446 : INFO : PROGRESS: at sentence #20000, processed 451892 words, keeping 24948 word types
# 2018-12-01 01:13:32,573 : INFO : PROGRESS: at sentence #30000, processed 671315 words, keeping 30034 word types
# 2018-12-01 01:13:32,645 : INFO : PROGRESS: at sentence #40000, processed 897815 words, keeping 34348 word types
# 2018-12-01 01:13:32,719 : INFO : PROGRESS: at sentence #50000, processed 1116963 words, keeping 37761 word types
# 2018-12-01 01:13:32,797 : INFO : PROGRESS: at sentence #60000, processed 1338404 words, keeping 40723 word types
# 2018-12-01 01:13:32,871 : INFO : PROGRESS: at sentence #70000, processed 1561580 words, keeping 43333 word types
# 2018-12-01 01:13:32,946 : INFO : PROGRESS: at sentence #80000, processed 1780887 words, keeping 45714 word types
# 2018-12-01 01:13:33,013 : INFO : PROGRESS: at sentence #90000, processed 2004996 words, keeping 48135 word types
# 2018-12-01 01:13:33,095 : INFO : PROGRESS: at sentence #100000, processed 2226966 words, keeping 50207 word types
# 2018-12-01 01:13:33,169 : INFO : PROGRESS: at sentence #110000, processed 2446580 words, keeping 52081 word types
# 2018-12-01 01:13:33,243 : INFO : PROGRESS: at sentence #120000, processed 2668775 words, keeping 54119 word types
# 2018-12-01 01:13:33,330 : INFO : PROGRESS: at sentence #130000, processed 2894303 words, keeping 55847 word types
# 2018-12-01 01:13:33,412 : INFO : PROGRESS: at sentence #140000, processed 3107005 words, keeping 57346 word types
# 2018-12-01 01:13:33,499 : INFO : PROGRESS: at sentence #150000, processed 3332627 words, keeping 59055 word types
# 2018-12-01 01:13:33,615 : INFO : PROGRESS: at sentence #160000, processed 3555315 words, keeping 60617 word types
# 2018-12-01 01:13:33,759 : INFO : PROGRESS: at sentence #170000, processed 3778655 words, keeping 62077 word types
# 2018-12-01 01:13:33,873 : INFO : PROGRESS: at sentence #180000, processed 3999236 words, keeping 63496 word types
# 2018-12-01 01:13:33,960 : INFO : PROGRESS: at sentence #190000, processed 4224449 words, keeping 64794 word types
# 2018-12-01 01:13:34,048 : INFO : PROGRESS: at sentence #200000, processed 4448603 words, keeping 66087 word types
# 2018-12-01 01:13:34,120 : INFO : PROGRESS: at sentence #210000, processed 4669967 words, keeping 67390 word types
# 2018-12-01 01:13:34,196 : INFO : PROGRESS: at sentence #220000, processed 4894968 words, keeping 68697 word types
# 2018-12-01 01:13:34,279 : INFO : PROGRESS: at sentence #230000, processed 5117545 words, keeping 69958 word types
# 2018-12-01 01:13:34,354 : INFO : PROGRESS: at sentence #240000, processed 5345050 words, keeping 71167 word types
# 2018-12-01 01:13:34,460 : INFO : PROGRESS: at sentence #250000, processed 5559165 words, keeping 72351 word types
# 2018-12-01 01:13:34,550 : INFO : PROGRESS: at sentence #260000, processed 5779146 words, keeping 73478 word types
# 2018-12-01 01:13:34,642 : INFO : PROGRESS: at sentence #270000, processed 6000435 words, keeping 74767 word types
# 2018-12-01 01:13:34,737 : INFO : PROGRESS: at sentence #280000, processed 6226314 words, keeping 76369 word types
# 2018-12-01 01:13:34,831 : INFO : PROGRESS: at sentence #290000, processed 6449474 words, keeping 77839 word types
# 2018-12-01 01:13:34,909 : INFO : PROGRESS: at sentence #300000, processed 6674077 words, keeping 79171 word types
# 2018-12-01 01:13:35,022 : INFO : PROGRESS: at sentence #310000, processed 6899391 words, keeping 80480 word types
# 2018-12-01 01:13:35,114 : INFO : PROGRESS: at sentence #320000, processed 7124278 words, keeping 81808 word types
# 2018-12-01 01:13:35,215 : INFO : PROGRESS: at sentence #330000, processed 7346021 words, keeping 83030 word types
# 2018-12-01 01:13:35,306 : INFO : PROGRESS: at sentence #340000, processed 7575533 words, keeping 84280 word types
# 2018-12-01 01:13:35,384 : INFO : PROGRESS: at sentence #350000, processed 7798803 words, keeping 85425 word types
# 2018-12-01 01:13:35,482 : INFO : PROGRESS: at sentence #360000, processed 8019427 words, keeping 86596 word types
# 2018-12-01 01:13:35,566 : INFO : PROGRESS: at sentence #370000, processed 8246619 words, keeping 87708 word types
# 2018-12-01 01:13:35,659 : INFO : PROGRESS: at sentence #380000, processed 8471766 words, keeping 88878 word types
# 2018-12-01 01:13:35,735 : INFO : PROGRESS: at sentence #390000, processed 8701497 words, keeping 89907 word types
# 2018-12-01 01:13:35,820 : INFO : PROGRESS: at sentence #400000, processed 8924446 words, keeping 90916 word types
# 2018-12-01 01:13:35,893 : INFO : PROGRESS: at sentence #410000, processed 9145796 words, keeping 91880 word types
# 2018-12-01 01:13:35,971 : INFO : PROGRESS: at sentence #420000, processed 9366876 words, keeping 92912 word types
# 2018-12-01 01:13:36,051 : INFO : PROGRESS: at sentence #430000, processed 9594413 words, keeping 93932 word types
# 2018-12-01 01:13:36,127 : INFO : PROGRESS: at sentence #440000, processed 9821166 words, keeping 94906 word types
# 2018-12-01 01:13:36,237 : INFO : PROGRESS: at sentence #450000, processed 10044928 words, keeping 96036 word types
# 2018-12-01 01:13:36,352 : INFO : PROGRESS: at sentence #460000, processed 10277688 words, keeping 97088 word types
# 2018-12-01 01:13:36,475 : INFO : PROGRESS: at sentence #470000, processed 10505613 words, keeping 97933 word types
# 2018-12-01 01:13:36,557 : INFO : PROGRESS: at sentence #480000, processed 10725997 words, keeping 98862 word types
# 2018-12-01 01:13:36,632 : INFO : PROGRESS: at sentence #490000, processed 10952741 words, keeping 99871 word types
# 2018-12-01 01:13:36,710 : INFO : PROGRESS: at sentence #500000, processed 11174397 words, keeping 100765 word types
# 2018-12-01 01:13:36,787 : INFO : PROGRESS: at sentence #510000, processed 11399672 words, keeping 101699 word types
# 2018-12-01 01:13:36,863 : INFO : PROGRESS: at sentence #520000, processed 11623020 words, keeping 102598 word types
# 2018-12-01 01:13:36,939 : INFO : PROGRESS: at sentence #530000, processed 11847418 words, keeping 103400 word types
# 2018-12-01 01:13:37,018 : INFO : PROGRESS: at sentence #540000, processed 12072033 words, keeping 104265 word types
# 2018-12-01 01:13:37,096 : INFO : PROGRESS: at sentence #550000, processed 12297571 words, keeping 105133 word types
# 2018-12-01 01:13:37,168 : INFO : PROGRESS: at sentence #560000, processed 12518861 words, keeping 105997 word types
# 2018-12-01 01:13:37,245 : INFO : PROGRESS: at sentence #570000, processed 12747916 words, keeping 106787 word types
# 2018-12-01 01:13:37,334 : INFO : PROGRESS: at sentence #580000, processed 12969412 words, keeping 107665 word types
# 2018-12-01 01:13:37,422 : INFO : PROGRESS: at sentence #590000, processed 13194937 words, keeping 108501 word types
# 2018-12-01 01:13:37,523 : INFO : PROGRESS: at sentence #600000, processed 13417135 words, keeping 109218 word types
# 2018-12-01 01:13:37,649 : INFO : PROGRESS: at sentence #610000, processed 13638158 words, keeping 110092 word types
# 2018-12-01 01:13:37,844 : INFO : PROGRESS: at sentence #620000, processed 13864483 words, keeping 110837 word types
# 2018-12-01 01:13:37,945 : INFO : PROGRESS: at sentence #630000, processed 14088769 words, keeping 111610 word types
# 2018-12-01 01:13:38,032 : INFO : PROGRESS: at sentence #640000, processed 14309552 words, keeping 112416 word types
# 2018-12-01 01:13:38,140 : INFO : PROGRESS: at sentence #650000, processed 14535308 words, keeping 113196 word types
# 2018-12-01 01:13:38,236 : INFO : PROGRESS: at sentence #660000, processed 14758098 words, keeping 113945 word types
# 2018-12-01 01:13:38,351 : INFO : PROGRESS: at sentence #670000, processed 14981482 words, keeping 114643 word types
# 2018-12-01 01:13:38,456 : INFO : PROGRESS: at sentence #680000, processed 15206314 words, keeping 115354 word types
# 2018-12-01 01:13:38,562 : INFO : PROGRESS: at sentence #690000, processed 15428507 words, keeping 116131 word types
# 2018-12-01 01:13:38,662 : INFO : PROGRESS: at sentence #700000, processed 15657213 words, keeping 116943 word types
# 2018-12-01 01:13:38,782 : INFO : PROGRESS: at sentence #710000, processed 15880202 words, keeping 117596 word types
# 2018-12-01 01:13:38,912 : INFO : PROGRESS: at sentence #720000, processed 16105489 words, keeping 118221 word types
# 2018-12-01 01:13:39,075 : INFO : PROGRESS: at sentence #730000, processed 16331870 words, keeping 118954 word types
# 2018-12-01 01:13:39,202 : INFO : PROGRESS: at sentence #740000, processed 16552903 words, keeping 119668 word types
# 2018-12-01 01:13:39,326 : INFO : PROGRESS: at sentence #750000, processed 16771230 words, keeping 120295 word types
# 2018-12-01 01:13:39,401 : INFO : PROGRESS: at sentence #760000, processed 16990622 words, keeping 120930 word types
# 2018-12-01 01:13:39,479 : INFO : PROGRESS: at sentence #770000, processed 17217759 words, keeping 121703 word types
# 2018-12-01 01:13:39,566 : INFO : PROGRESS: at sentence #780000, processed 17447905 words, keeping 122402 word types
# 2018-12-01 01:13:39,644 : INFO : PROGRESS: at sentence #790000, processed 17674981 words, keeping 123066 word types
# 2018-12-01 01:13:39,687 : INFO : collected 123504 word types from a corpus of 17798082 raw words and 795538 sentences
# 2018-12-01 01:13:39,688 : INFO : Loading a fresh vocabulary
# 2018-12-01 01:13:39,820 : INFO : min_count=40 retains 16490 unique words (13% of original 123504, drops 107014)
# 2018-12-01 01:13:39,821 : INFO : min_count=40 leaves 17238940 word corpus (96% of original 17798082, drops 559142)
# 2018-12-01 01:13:39,929 : INFO : deleting the raw counts dictionary of 123504 items
# 2018-12-01 01:13:39,936 : INFO : sample=0.001 downsamples 48 most-common words
# 2018-12-01 01:13:39,938 : INFO : downsampling leaves estimated 12749658 word corpus (74.0% of prior 17238940)
# 2018-12-01 01:13:40,037 : INFO : estimated required memory for 16490 words and 300 dimensions: 47821000 bytes
# 2018-12-01 01:13:40,037 : INFO : resetting layer weights
# 2018-12-01 01:13:40,784 : INFO : training model with 4 workers on 16490 vocabulary and 300 features, using sg=0 hs=0 sample=0.001 negative=5 window=10
# 2018-12-01 01:13:41,830 : INFO : EPOCH 1 - PROGRESS: at 2.91% examples, 361441 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:13:42,845 : INFO : EPOCH 1 - PROGRESS: at 6.18% examples, 384919 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:13:43,874 : INFO : EPOCH 1 - PROGRESS: at 9.18% examples, 379198 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:13:44,876 : INFO : EPOCH 1 - PROGRESS: at 12.45% examples, 387728 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:13:45,894 : INFO : EPOCH 1 - PROGRESS: at 15.73% examples, 391772 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:13:46,910 : INFO : EPOCH 1 - PROGRESS: at 18.75% examples, 388552 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:13:47,930 : INFO : EPOCH 1 - PROGRESS: at 21.92% examples, 389155 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:13:48,948 : INFO : EPOCH 1 - PROGRESS: at 24.78% examples, 385367 words/s, in_qsize 8, out_qsize 1
# 2018-12-01 01:13:49,972 : INFO : EPOCH 1 - PROGRESS: at 28.15% examples, 389046 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:13:50,978 : INFO : EPOCH 1 - PROGRESS: at 31.37% examples, 390601 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:13:51,993 : INFO : EPOCH 1 - PROGRESS: at 34.49% examples, 390254 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:13:53,085 : INFO : EPOCH 1 - PROGRESS: at 37.45% examples, 386406 words/s, in_qsize 8, out_qsize 1
# 2018-12-01 01:13:54,102 : INFO : EPOCH 1 - PROGRESS: at 40.18% examples, 383260 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:13:55,109 : INFO : EPOCH 1 - PROGRESS: at 42.69% examples, 378783 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:13:56,112 : INFO : EPOCH 1 - PROGRESS: at 45.94% examples, 381064 words/s, in_qsize 8, out_qsize 1
# 2018-12-01 01:13:57,151 : INFO : EPOCH 1 - PROGRESS: at 48.71% examples, 378701 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:13:58,162 : INFO : EPOCH 1 - PROGRESS: at 51.99% examples, 380536 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:13:59,163 : INFO : EPOCH 1 - PROGRESS: at 54.87% examples, 380030 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:14:00,173 : INFO : EPOCH 1 - PROGRESS: at 57.57% examples, 378273 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:14:01,181 : INFO : EPOCH 1 - PROGRESS: at 60.41% examples, 377478 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:14:02,192 : INFO : EPOCH 1 - PROGRESS: at 62.77% examples, 373655 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:14:03,225 : INFO : EPOCH 1 - PROGRESS: at 65.29% examples, 370815 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:14:04,225 : INFO : EPOCH 1 - PROGRESS: at 67.81% examples, 368729 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:14:05,239 : INFO : EPOCH 1 - PROGRESS: at 70.16% examples, 365719 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:14:06,243 : INFO : EPOCH 1 - PROGRESS: at 72.44% examples, 362815 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:14:07,249 : INFO : EPOCH 1 - PROGRESS: at 75.64% examples, 364443 words/s, in_qsize 6, out_qsize 1
# 2018-12-01 01:14:08,259 : INFO : EPOCH 1 - PROGRESS: at 78.73% examples, 365338 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:14:09,265 : INFO : EPOCH 1 - PROGRESS: at 82.21% examples, 368000 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:14:10,278 : INFO : EPOCH 1 - PROGRESS: at 85.68% examples, 370408 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:14:11,279 : INFO : EPOCH 1 - PROGRESS: at 89.15% examples, 372793 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:14:12,304 : INFO : EPOCH 1 - PROGRESS: at 92.56% examples, 374509 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:14:13,307 : INFO : EPOCH 1 - PROGRESS: at 95.76% examples, 375270 words/s, in_qsize 8, out_qsize 1
# 2018-12-01 01:14:14,308 : INFO : EPOCH 1 - PROGRESS: at 98.77% examples, 375808 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:14:14,634 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-12-01 01:14:14,642 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-12-01 01:14:14,676 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-12-01 01:14:14,684 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-12-01 01:14:14,686 : INFO : EPOCH - 1 : training on 17798082 raw words (12748898 effective words) took 33.9s, 376235 effective words/s
# 2018-12-01 01:14:15,709 : INFO : EPOCH 2 - PROGRESS: at 2.85% examples, 362336 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:14:16,732 : INFO : EPOCH 2 - PROGRESS: at 5.76% examples, 362656 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:14:17,748 : INFO : EPOCH 2 - PROGRESS: at 9.00% examples, 375458 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:14:18,757 : INFO : EPOCH 2 - PROGRESS: at 11.56% examples, 361463 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:14:19,768 : INFO : EPOCH 2 - PROGRESS: at 14.29% examples, 357137 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:14:20,779 : INFO : EPOCH 2 - PROGRESS: at 16.95% examples, 353086 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:14:21,779 : INFO : EPOCH 2 - PROGRESS: at 19.38% examples, 346570 words/s, in_qsize 7, out_qsize 1
# 2018-12-01 01:14:22,794 : INFO : EPOCH 2 - PROGRESS: at 22.03% examples, 344621 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:14:23,804 : INFO : EPOCH 2 - PROGRESS: at 25.57% examples, 355854 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:14:24,818 : INFO : EPOCH 2 - PROGRESS: at 28.70% examples, 359684 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:14:25,861 : INFO : EPOCH 2 - PROGRESS: at 32.07% examples, 363866 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:14:26,875 : INFO : EPOCH 2 - PROGRESS: at 35.56% examples, 369957 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:14:27,881 : INFO : EPOCH 2 - PROGRESS: at 38.28% examples, 368310 words/s, in_qsize 8, out_qsize 1
# 2018-12-01 01:14:28,901 : INFO : EPOCH 2 - PROGRESS: at 41.65% examples, 372162 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:14:29,916 : INFO : EPOCH 2 - PROGRESS: at 44.89% examples, 374587 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:14:30,921 : INFO : EPOCH 2 - PROGRESS: at 47.89% examples, 375156 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:14:31,930 : INFO : EPOCH 2 - PROGRESS: at 51.42% examples, 379367 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:14:32,934 : INFO : EPOCH 2 - PROGRESS: at 54.43% examples, 379653 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:14:33,978 : INFO : EPOCH 2 - PROGRESS: at 57.63% examples, 380561 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:14:34,991 : INFO : EPOCH 2 - PROGRESS: at 60.85% examples, 382014 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:14:36,003 : INFO : EPOCH 2 - PROGRESS: at 63.95% examples, 382323 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:14:37,008 : INFO : EPOCH 2 - PROGRESS: at 67.18% examples, 383719 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:14:38,020 : INFO : EPOCH 2 - PROGRESS: at 70.49% examples, 385167 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:14:39,033 : INFO : EPOCH 2 - PROGRESS: at 73.62% examples, 385585 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:14:40,061 : INFO : EPOCH 2 - PROGRESS: at 76.93% examples, 386591 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:14:41,082 : INFO : EPOCH 2 - PROGRESS: at 80.20% examples, 387351 words/s, in_qsize 7, out_qsize 1
# 2018-12-01 01:14:42,098 : INFO : EPOCH 2 - PROGRESS: at 83.17% examples, 386809 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:14:43,114 : INFO : EPOCH 2 - PROGRESS: at 86.53% examples, 388093 words/s, in_qsize 8, out_qsize 1
# 2018-12-01 01:14:44,145 : INFO : EPOCH 2 - PROGRESS: at 89.85% examples, 389057 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:14:45,151 : INFO : EPOCH 2 - PROGRESS: at 92.95% examples, 389141 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:14:46,191 : INFO : EPOCH 2 - PROGRESS: at 96.47% examples, 390369 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:14:47,226 : INFO : EPOCH 2 - PROGRESS: at 99.66% examples, 390705 words/s, in_qsize 6, out_qsize 0
# 2018-12-01 01:14:47,264 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-12-01 01:14:47,308 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-12-01 01:14:47,320 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-12-01 01:14:47,328 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-12-01 01:14:47,331 : INFO : EPOCH - 2 : training on 17798082 raw words (12749339 effective words) took 32.6s, 390756 effective words/s
# 2018-12-01 01:14:48,349 : INFO : EPOCH 3 - PROGRESS: at 2.85% examples, 362193 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:14:49,359 : INFO : EPOCH 3 - PROGRESS: at 6.15% examples, 389796 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:14:50,371 : INFO : EPOCH 3 - PROGRESS: at 9.45% examples, 396262 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:14:51,383 : INFO : EPOCH 3 - PROGRESS: at 12.63% examples, 396229 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:14:52,404 : INFO : EPOCH 3 - PROGRESS: at 16.11% examples, 403980 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:14:53,433 : INFO : EPOCH 3 - PROGRESS: at 19.38% examples, 402539 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:14:54,444 : INFO : EPOCH 3 - PROGRESS: at 22.48% examples, 400709 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:14:55,447 : INFO : EPOCH 3 - PROGRESS: at 26.02% examples, 406599 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:14:56,462 : INFO : EPOCH 3 - PROGRESS: at 29.04% examples, 403696 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:14:57,478 : INFO : EPOCH 3 - PROGRESS: at 32.13% examples, 401286 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:14:58,510 : INFO : EPOCH 3 - PROGRESS: at 34.65% examples, 392966 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:14:59,515 : INFO : EPOCH 3 - PROGRESS: at 37.34% examples, 388761 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:15:00,533 : INFO : EPOCH 3 - PROGRESS: at 40.35% examples, 388036 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:15:01,557 : INFO : EPOCH 3 - PROGRESS: at 43.64% examples, 389810 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:15:02,568 : INFO : EPOCH 3 - PROGRESS: at 46.72% examples, 389724 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:15:03,587 : INFO : EPOCH 3 - PROGRESS: at 50.00% examples, 391256 words/s, in_qsize 7, out_qsize 1
# 2018-12-01 01:15:04,602 : INFO : EPOCH 3 - PROGRESS: at 53.32% examples, 392720 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:15:05,626 : INFO : EPOCH 3 - PROGRESS: at 56.38% examples, 392189 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:15:06,629 : INFO : EPOCH 3 - PROGRESS: at 59.78% examples, 394796 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:15:07,639 : INFO : EPOCH 3 - PROGRESS: at 62.94% examples, 394875 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:15:08,657 : INFO : EPOCH 3 - PROGRESS: at 66.06% examples, 394803 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:15:09,662 : INFO : EPOCH 3 - PROGRESS: at 69.48% examples, 396574 words/s, in_qsize 8, out_qsize 1
# 2018-12-01 01:15:10,696 : INFO : EPOCH 3 - PROGRESS: at 72.21% examples, 394020 words/s, in_qsize 6, out_qsize 1
# 2018-12-01 01:15:11,718 : INFO : EPOCH 3 - PROGRESS: at 75.42% examples, 394236 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:15:12,728 : INFO : EPOCH 3 - PROGRESS: at 78.79% examples, 395449 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:15:13,742 : INFO : EPOCH 3 - PROGRESS: at 81.70% examples, 394328 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:15:14,752 : INFO : EPOCH 3 - PROGRESS: at 85.00% examples, 395206 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:15:15,779 : INFO : EPOCH 3 - PROGRESS: at 88.13% examples, 395002 words/s, in_qsize 8, out_qsize 1
# 2018-12-01 01:15:16,797 : INFO : EPOCH 3 - PROGRESS: at 90.98% examples, 393727 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:15:17,807 : INFO : EPOCH 3 - PROGRESS: at 94.26% examples, 394287 words/s, in_qsize 8, out_qsize 2
# 2018-12-01 01:15:18,848 : INFO : EPOCH 3 - PROGRESS: at 97.46% examples, 394221 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:15:19,542 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-12-01 01:15:19,549 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-12-01 01:15:19,575 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-12-01 01:15:19,599 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-12-01 01:15:19,605 : INFO : EPOCH - 3 : training on 17798082 raw words (12748670 effective words) took 32.3s, 395138 effective words/s
# 2018-12-01 01:15:20,636 : INFO : EPOCH 4 - PROGRESS: at 3.02% examples, 386413 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:15:21,648 : INFO : EPOCH 4 - PROGRESS: at 6.04% examples, 383838 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:15:22,656 : INFO : EPOCH 4 - PROGRESS: at 9.57% examples, 402328 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:15:23,677 : INFO : EPOCH 4 - PROGRESS: at 12.80% examples, 401726 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:15:24,695 : INFO : EPOCH 4 - PROGRESS: at 15.79% examples, 395813 words/s, in_qsize 8, out_qsize 2
# 2018-12-01 01:15:25,698 : INFO : EPOCH 4 - PROGRESS: at 19.26% examples, 402243 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:15:26,703 : INFO : EPOCH 4 - PROGRESS: at 22.32% examples, 399718 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:15:27,707 : INFO : EPOCH 4 - PROGRESS: at 25.10% examples, 394254 words/s, in_qsize 8, out_qsize 2
# 2018-12-01 01:15:28,716 : INFO : EPOCH 4 - PROGRESS: at 28.15% examples, 392951 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:15:29,723 : INFO : EPOCH 4 - PROGRESS: at 31.20% examples, 391947 words/s, in_qsize 8, out_qsize 1
# 2018-12-01 01:15:30,746 : INFO : EPOCH 4 - PROGRESS: at 34.65% examples, 395063 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:15:31,759 : INFO : EPOCH 4 - PROGRESS: at 37.84% examples, 395719 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:15:32,773 : INFO : EPOCH 4 - PROGRESS: at 41.03% examples, 396192 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:15:33,775 : INFO : EPOCH 4 - PROGRESS: at 44.38% examples, 398487 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:15:34,780 : INFO : EPOCH 4 - PROGRESS: at 47.56% examples, 398965 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:15:35,794 : INFO : EPOCH 4 - PROGRESS: at 50.68% examples, 398711 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:15:36,796 : INFO : EPOCH 4 - PROGRESS: at 54.15% examples, 401270 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:15:37,801 : INFO : EPOCH 4 - PROGRESS: at 57.15% examples, 400312 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:15:38,802 : INFO : EPOCH 4 - PROGRESS: at 60.25% examples, 400262 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:15:39,815 : INFO : EPOCH 4 - PROGRESS: at 63.60% examples, 401454 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:15:40,816 : INFO : EPOCH 4 - PROGRESS: at 66.69% examples, 401029 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:15:41,834 : INFO : EPOCH 4 - PROGRESS: at 70.05% examples, 401986 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:15:42,843 : INFO : EPOCH 4 - PROGRESS: at 73.28% examples, 402380 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:15:43,852 : INFO : EPOCH 4 - PROGRESS: at 76.49% examples, 402438 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:15:44,879 : INFO : EPOCH 4 - PROGRESS: at 79.80% examples, 402800 words/s, in_qsize 6, out_qsize 1
# 2018-12-01 01:15:45,885 : INFO : EPOCH 4 - PROGRESS: at 83.17% examples, 403703 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:15:46,898 : INFO : EPOCH 4 - PROGRESS: at 86.25% examples, 403130 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:15:47,928 : INFO : EPOCH 4 - PROGRESS: at 89.63% examples, 403883 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:15:48,931 : INFO : EPOCH 4 - PROGRESS: at 92.68% examples, 403251 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:15:49,943 : INFO : EPOCH 4 - PROGRESS: at 95.86% examples, 403002 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:15:50,946 : INFO : EPOCH 4 - PROGRESS: at 99.11% examples, 403567 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:15:51,194 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-12-01 01:15:51,199 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-12-01 01:15:51,242 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-12-01 01:15:51,246 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-12-01 01:15:51,247 : INFO : EPOCH - 4 : training on 17798082 raw words (12749811 effective words) took 31.6s, 403325 effective words/s
# 2018-12-01 01:15:52,282 : INFO : EPOCH 5 - PROGRESS: at 3.36% examples, 424745 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:15:53,299 : INFO : EPOCH 5 - PROGRESS: at 6.45% examples, 405579 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:15:54,318 : INFO : EPOCH 5 - PROGRESS: at 9.86% examples, 410752 words/s, in_qsize 8, out_qsize 1
# 2018-12-01 01:15:55,322 : INFO : EPOCH 5 - PROGRESS: at 12.87% examples, 402615 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:15:56,323 : INFO : EPOCH 5 - PROGRESS: at 15.90% examples, 399340 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:15:57,335 : INFO : EPOCH 5 - PROGRESS: at 19.26% examples, 402214 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:15:58,360 : INFO : EPOCH 5 - PROGRESS: at 22.59% examples, 403521 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:15:59,381 : INFO : EPOCH 5 - PROGRESS: at 25.75% examples, 402043 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:16:00,408 : INFO : EPOCH 5 - PROGRESS: at 29.04% examples, 403034 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:16:01,417 : INFO : EPOCH 5 - PROGRESS: at 32.34% examples, 403774 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:16:02,442 : INFO : EPOCH 5 - PROGRESS: at 35.56% examples, 403177 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:16:03,452 : INFO : EPOCH 5 - PROGRESS: at 38.96% examples, 405636 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:16:04,452 : INFO : EPOCH 5 - PROGRESS: at 42.14% examples, 405774 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:16:05,501 : INFO : EPOCH 5 - PROGRESS: at 45.51% examples, 406007 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:16:06,508 : INFO : EPOCH 5 - PROGRESS: at 48.82% examples, 407356 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:16:07,537 : INFO : EPOCH 5 - PROGRESS: at 51.99% examples, 406194 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:16:08,539 : INFO : EPOCH 5 - PROGRESS: at 55.38% examples, 407885 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:16:09,546 : INFO : EPOCH 5 - PROGRESS: at 58.63% examples, 408460 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:16:10,565 : INFO : EPOCH 5 - PROGRESS: at 61.70% examples, 407266 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:16:11,581 : INFO : EPOCH 5 - PROGRESS: at 65.07% examples, 408033 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:16:12,583 : INFO : EPOCH 5 - PROGRESS: at 68.21% examples, 407633 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:16:13,593 : INFO : EPOCH 5 - PROGRESS: at 71.33% examples, 407142 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:16:14,607 : INFO : EPOCH 5 - PROGRESS: at 74.80% examples, 408457 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:16:15,610 : INFO : EPOCH 5 - PROGRESS: at 77.89% examples, 407783 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:16:16,652 : INFO : EPOCH 5 - PROGRESS: at 81.10% examples, 407085 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:16:17,656 : INFO : EPOCH 5 - PROGRESS: at 84.56% examples, 408399 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:16:18,675 : INFO : EPOCH 5 - PROGRESS: at 87.69% examples, 407841 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:16:19,700 : INFO : EPOCH 5 - PROGRESS: at 91.04% examples, 408227 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:16:20,709 : INFO : EPOCH 5 - PROGRESS: at 94.38% examples, 408570 words/s, in_qsize 7, out_qsize 0
# 2018-12-01 01:16:21,713 : INFO : EPOCH 5 - PROGRESS: at 97.46% examples, 408010 words/s, in_qsize 8, out_qsize 0
# 2018-12-01 01:16:22,400 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-12-01 01:16:22,418 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-12-01 01:16:22,445 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-12-01 01:16:22,448 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-12-01 01:16:22,449 : INFO : EPOCH - 5 : training on 17798082 raw words (12749291 effective words) took 31.2s, 408930 effective words/s
# 2018-12-01 01:16:22,451 : INFO : training on a 88990410 raw words (63746009 effective words) took 161.7s, 394307 effective words/s
# 2018-12-01 01:16:22,453 : INFO : precomputing L2-norms of word weight vectors
# 2018-12-01 01:16:22,841 : INFO : saving Word2Vec object under 300features_40minwords_10context, separately None
# 2018-12-01 01:16:22,843 : INFO : not storing attribute vectors_norm
# 2018-12-01 01:16:22,845 : INFO : not storing attribute cum_table
# 2018-12-01 01:16:24,494 : INFO : saved 300features_40minwords_10context
